# %%
import webbrowser
import requests
from bs4 import BeautifulSoup

# %%
def openyoutube(string):
    
    print(string)
    
    urlforytb="https://www.youtube.com/results?search_query={}".format(string)
    print(urlforytb)
    ytburl=requests.get(urlforytb).text
    
    soup=BeautifulSoup(ytburl,'lxml')
#     print(soup.prettify())
    
    urldict=[]
    
    codeintring=soup.text
    codeintring

    for i in range(len(codeintring)):
        if codeintring[i]=='w' and codeintring[i+2]=='t' and codeintring[i+4]=='h' and codeintring[i+5]=='?':
            j=0
    #         print(codeintring[i:i+19])
    #         for k in range(0,40):
    #             if codeintring[i+k]=='"':
    #                 j=k
    #                 break
            urldict.append(codeintring[i:i+19])
        
    print(urldict)
    
    urlofyotuube="https://www.youtube.com/{}".format(urldict[0])

    webbrowser.open(urlofyotuube)
    
    print(urlofyotuube)

# %%
string=input()

string=string.replace("song","music")
print(string)
songname=""
for i in range(len(string)):
    if string[i]=='m' and string[i+1]=='u' and string[i+2]=='s' and string[i+3]=='i' and string[i+4]=='c':
        songname=string[i+6:]
        break
        
print(songname)
        
openyoutube(songname)
# Out:
# play the song you are my sonia
# play the music you are my sonia
# you are my sonia
# you are my sonia
# https://www.youtube.com/results?search_query=you are my sonia
# ['watch?v=DwUgoUhgzLo', 'watch?v=te9CwDUz-9I', 'watch?v=powJxf--bJw', 'watch?v=JUQETR7Hq58', 'watch?v=avuWWztS-6k', 'watch?v=B6avf8lfkGk', 'watch?v=zumMQrI_tMg', 'watch?v=YsLocUD27cI', 'watch?v=Sz67LakJbF4', 'watch?v=KrlWOGePVzk', 'watch?v=Ccr0S_HxvC4', 'watch?v=pgTPDOhF4RI', 'watch?v=enXLotpUDrM', 'watch?v=cKgpoNKUfwc', 'watch?v=CGbvgeBg3mI', 'watch?v=3NWMK2MRqIk', 'watch?v=y2pBnyUfsHo', 'watch?v=OpTySRpMDvw', 'watch?v=ICv2_UW7GHM', 'watch?v=FeK4qlewdpQ', 'watch?v=pQWK4d7LYMU', 'watch?v=4JWyj2e5g-s', 'watch?v=Ha39Svtc1D8', 'watch?v=ap_p1pb6Wfg', 'watch?v=DwUgoUhgzLo', 'watch?v=DwUgoUhgzLo', 'watch?v=7rL_PsEfpFs', 'watch?v=KbA_PmTWvo8', 'watch?v=sr-FH4J3XxQ', 'watch?v=wl_OeUzkV1E', 'watch?v=x6ZqHcVFyk0', 'watch?v=F0q8FDF0z0U']
# https://www.youtube.com/watch?v=DwUgoUhgzLo

# %%
# Out:
# https://www.youtube.com/results?search_query= chand sa raushan chehra

# %%
while True:
    front=ears()

    if "kate" in front:

        while True:

            task=ears()
            
            task=task.replace("song","music")

            if "music" in task:
                
                songname=""
                
                for i in range(len(string)):
                    if string[i]=='m' and string[i+1]=='u' and string[i+2]=='s' and string[i+3]=='i' and string[i+4]=='c':
                        songname=string[i+6:]
                        break

                print(songname)

                openyoutube(songname)
                
            else:
                
                google_search(task)
# Out:
# <!DOCTYPE html>
# <html lang="en-GB" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing="">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script nonce="Qq01ZeiGHZkMPlvUuO2dkg">
#    var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# window.ytcfg.set('EMERGENCY_BASE_URL', '\/error_204?t\x3djserror\x26level\x3dERROR\x26client.name\x3d1\x26client.version\x3d2.20220110.00.00');
#   </script>
#   <script nonce="Qq01ZeiGHZkMPlvUuO2dkg">
#    (function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;
# ...

# %%
# Out:
# 'var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};\nwindow.ytcfg.set(\'EMERGENCY_BASE_URL\', \'\\/error_204?t\\x3djserror\\x26level\\x3dERROR\\x26client.name\\x3d1\\x26client.version\\x3d2.20220110.00.00\');(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber))err["columnNumber"]=columnNumber}var message=String(err.message);if(!err.message||message in window.unhandledErrorMessages||window.unhandledErrorCount>=5)return;window.unhandledErrorCount+=1;window.unhandledErrorMessages[message]=true;var img=new Image;window.emergencyTimeoutImg=img;im
# ...

# %%
"bhi" in "abhish"
# Out:
# True

# %%
#         i=i+j

# %%
# Out:
# ['watch?v=VueN49P7JyU',
#  'watch?v=ApPI3Qiai1o',
#  'watch?v=mKnFLXJwmu4',
#  'watch?v=cP4AZ9zhVtM',
#  'watch?v=TvngY4unjn4',
#  'watch?v=EVSFFiAcWqs',
#  'watch?v=S0WPSYFm7iE',
#  'watch?v=RxJYOb7K1zc',
#  'watch?v=4HRC6c5-2lQ',
#  'watch?v=yIzCBU0_LyY',
#  'watch?v=O0I61W2pMss',
#  'watch?v=MkABeVCv4lw',
#  'watch?v=XR7qvTgQ19o',
#  'watch?v=JpzRpOd8WIk',
#  'watch?v=hgi2MYAFgE8',
#  'watch?v=U586et5k8DQ',
#  'watch?v=JlgkMXex2DI',
#  'watch?v=BOYlxHAwqYo',
#  'watch?v=jgYl4hZacx0',
#  'watch?v=n2LfJhj5WZ0',
#  'watch?v=tpWiDOCG1wo',
#  'watch?v=q8yGHwP1nuw',
#  'watch?v=-s5E8bP2ve4',
#  'watch?v=ncvayOH_MTA',
#  'watch?v=PZ-hlJwpvXo',
#  'watch?v=6Kthe4OgjNs',
#  'watch?v=zeUv3PHOmx8',
#  'watch?v=gvLNCvK14eg',
#  'watch?v=VCbOu5vj6is',
#  'watch?v=3KPFgaAftOs']

# %%
urlofyotuube="https://www.youtube.com/{}".format(urldict[0])

webbrowser.open(urlofyotuube)
# Out:
# True

# %%
urlofyotuube
# Out:
# 'https://www.youtube.com/'
